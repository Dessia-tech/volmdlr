# %% [markdown]
# # Initializing Google Colab

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2022-08-16 11:00:14--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   154MB/s    in 0.6s
#
# 2022-08-16 11:00:15 (154 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
# Reload the web page (quit) and execute this cell
import sys
print("User Current Version:-", sys.version)
if sys.version[:3] != "3.8":
  raise SystemError("Try to reload the web page (quit)")
# Out:
# User Current Version:- 3.8.1 (default, Jan  8 2020, 22:29:32)
# [GCC 7.3.0]

# %% [markdown]
# # Tutorial

# %%
# !pip install dessia_common
# !pip install volmdlr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from IPython.display import HTML

import math

import volmdlr as vm
import volmdlr.core as vmc
import volmdlr.primitives3d as p3d

# %%
frame = vm.Frame3D(origin=vm.Point3D(1, 1, 1),
                   u=vm.Vector3D(2, 0, 0),
                   v=vm.Vector3D(0, 0.5, 0),
                   w=vm.Vector3D(0, 0, 1))
block1 = p3d.Block(frame=frame, color=(1, 0, 0))
block1.save_babylonjs_to_file(filename='/tmp/block1')
HTML(filename='/tmp/block1.html')
# Out:
# <!doctype html>
# <html>
# <head>
#    <meta charset="utf-8">
#    <title>Babylon from volmdlr</title>
#    <style>
#       html, body {
#          overflow: hidden;
#          width: 100%;
#          height: 100%;
#          margin: 0;
#          padding: 0;
#       }
#       #renderCanvas {
#          width: 100%;
#          height: 100%;
#          touch-action: none;
#       }
#    </style>
#       <script src="https://cdn.babylonjs.com/babylon.js"></script>
#       <script src="https://cdn.babylonjs.com/loaders/babylonjs.loaders.min.js"></script>
#       <script src="https://code.jquery.com/pep/0.4.3/pep.js"></script>
#       <script src='https://unpkg.com/earcut@2.1.1/dist/earcut.min.js'></script>
#       <script src='https://cdn.babylonjs.com/gui/babylon.gui.min.js'></script>
# </head>
#
# <body>
#    <canvas id="renderCanvas"></canvas>
#    <script type="text/javascript">
#       // Get the canvas element from our HTML below
# ...

# %%
frame = vm.Frame3D(origin=vm.O3D,
                   u=vm.Vector3D(2, 0, 0),
                   v=vm.Vector3D(0, 0.5, 0),
                   w=vm.Z3D)
block2 = p3d.Block(frame=frame,
                   color=(0, 0, 1))
block2.rotation(center=vm.O3D,
                axis=vm.Y3D,
                angle=math.pi/4,
                copy=False)
block2.rotation(center=vm.O3D,
                axis=(vm.X3D + vm.Z3D)/2**0.5,
                angle=math.pi/2,
                copy=False)
block2.translation(offset=vm.Z3D, copy=False)
volume_model = vmc.VolumeModel([block1, block2])
volume_model.save_babylonjs_to_file(filename='/tmp/volume_model')
HTML(filename='/tmp/volume_model.html')
# Out:
# <!doctype html>
# <html>
# <head>
#    <meta charset="utf-8">
#    <title>Babylon from volmdlr</title>
#    <style>
#       html, body {
#          overflow: hidden;
#          width: 100%;
#          height: 100%;
#          margin: 0;
#          padding: 0;
#       }
#       #renderCanvas {
#          width: 100%;
#          height: 100%;
#          touch-action: none;
#       }
#    </style>
#       <script src="https://cdn.babylonjs.com/babylon.js"></script>
#       <script src="https://cdn.babylonjs.com/loaders/babylonjs.loaders.min.js"></script>
#       <script src="https://code.jquery.com/pep/0.4.3/pep.js"></script>
#       <script src='https://unpkg.com/earcut@2.1.1/dist/earcut.min.js'></script>
#       <script src='https://cdn.babylonjs.com/gui/babylon.gui.min.js'></script>
# </head>
#
# <body>
#    <canvas id="renderCanvas"></canvas>
#    <script type="text/javascript">
#       // Get the canvas element from our HTML below
# ...

# %%
unions = block1.union(block2)
print(unions)

unions[0].save_babylonjs_to_file(filename='/tmp/union')
HTML(filename='/tmp/union.html')
# Out:
# ...
# <!doctype html>
# <html>
# <head>
#    <meta charset="utf-8">
#    <title>Babylon from volmdlr</title>
#    <style>
#       html, body {
#          overflow: hidden;
#          width: 100%;
#          height: 100%;
#          margin: 0;
#          padding: 0;
#       }
#       #renderCanvas {
#          width: 100%;
#          height: 100%;
#          touch-action: none;
#       }
#    </style>
#       <script src="https://cdn.babylonjs.com/babylon.js"></script>
#       <script src="https://cdn.babylonjs.com/loaders/babylonjs.loaders.min.js"></script>
#       <script src="https://code.jquery.com/pep/0.4.3/pep.js"></script>
#       <script src='https://unpkg.com/earcut@2.1.1/dist/earcut.min.js'></script>
#       <script src='https://cdn.babylonjs.com/gui/babylon.gui.min.js'></script>
# </head>
#
# <body>
#    <canvas id="renderCanvas"></canvas>
#    <script type="text/javascript">
#       // Get the canvas element from our HTML below
# ...

# %%
intersections = block1.intersection(block2)
print(intersections)

intersections[0].save_babylonjs_to_file(filename='/tmp/intersection')
HTML(filename='/tmp/intersection.html')
# Out:
# ...
# <!doctype html>
# <html>
# <head>
#    <meta charset="utf-8">
#    <title>Babylon from volmdlr</title>
#    <style>
#       html, body {
#          overflow: hidden;
#          width: 100%;
#          height: 100%;
#          margin: 0;
#          padding: 0;
#       }
#       #renderCanvas {
#          width: 100%;
#          height: 100%;
#          touch-action: none;
#       }
#    </style>
#       <script src="https://cdn.babylonjs.com/babylon.js"></script>
#       <script src="https://cdn.babylonjs.com/loaders/babylonjs.loaders.min.js"></script>
#       <script src="https://code.jquery.com/pep/0.4.3/pep.js"></script>
#       <script src='https://unpkg.com/earcut@2.1.1/dist/earcut.min.js'></script>
#       <script src='https://cdn.babylonjs.com/gui/babylon.gui.min.js'></script>
# </head>
#
# <body>
#    <canvas id="renderCanvas"></canvas>
#    <script type="text/javascript">
#       // Get the canvas element from our HTML below
# ...

# %%
block1.alpha = 0.2
block2.alpha = 0.2
intersections[0].color = (0, 1, 0)
intersection_volume_model = vmc.VolumeModel(primitives=[block1, block2, intersections[0]])

intersection_volume_model.save_babylonjs_to_file(filename='/tmp/intersection_volume_model')
HTML(filename='/tmp/intersection_volume_model.html')
# Out:
# <!doctype html>
# <html>
# <head>
#    <meta charset="utf-8">
#    <title>Babylon from volmdlr</title>
#    <style>
#       html, body {
#          overflow: hidden;
#          width: 100%;
#          height: 100%;
#          margin: 0;
#          padding: 0;
#       }
#       #renderCanvas {
#          width: 100%;
#          height: 100%;
#          touch-action: none;
#       }
#    </style>
#       <script src="https://cdn.babylonjs.com/babylon.js"></script>
#       <script src="https://cdn.babylonjs.com/loaders/babylonjs.loaders.min.js"></script>
#       <script src="https://code.jquery.com/pep/0.4.3/pep.js"></script>
#       <script src='https://unpkg.com/earcut@2.1.1/dist/earcut.min.js'></script>
#       <script src='https://cdn.babylonjs.com/gui/babylon.gui.min.js'></script>
# </head>
#
# <body>
#    <canvas id="renderCanvas"></canvas>
#    <script type="text/javascript">
#       // Get the canvas element from our HTML below
# ...
